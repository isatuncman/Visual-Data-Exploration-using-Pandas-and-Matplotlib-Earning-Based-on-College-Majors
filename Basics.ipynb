# %%
#Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Introduction to Dataset

# %%
#Read and explore dataset
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# ## Missing Data Analysis

# %%
raw_data_count = len(recent_grads)
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = len(recent_grads)
cleaned_data_count
# Out:
# 172

# %% [markdown]
# There exist only one row which has missing values in raw dataset

# %% [markdown]
# # Visual Exploration of the Dataset

# %% [markdown]
# ## Scatterplots

# %% [markdown]
# __1)__ Sample Size vs Median

# %%
recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'scatter', title='Sample_size vs. Median')

# %% [markdown]
# __2)__ Sample_size vs Unemployment_rate

# %%
recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate', kind = 'Scatter', title = 'Sample_size vs Unemployment Rate')
plt.show()

# %% [markdown]
# There seems to be no clear relationship between Popularity of a Major and Salary or Unemployment Rate. However, we can say that popular majors make moderate amount of money and have moderate unemployment rate.

# %% [markdown]
# __3)__ Full time vs Median

# %%
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'Scatter', title = 'Full_time vs Median')
plt.show()

# %% [markdown]
# There seems to be no relationship betwen being a full time employee and median salary

# %% [markdown]
# __4)__ Full time vs Median

# %%
recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate', kind = 'scatter' , title = 'Sharewoman vs Unemployment_rate')
plt.show()

# %% [markdown]
# __5)__ Men vs Median

# %%
recent_grads.plot(x = 'Men', y = 'Median', kind = 'scatter', title = 'Men vs Median')
plt.show()

# %% [markdown]
# __6)__ Women vs Median

# %%
recent_grads.plot(x = 'Women', y = 'Median', kind = 'Scatter', title = 'Women vs Median')
plt.show()

# %% [markdown]
# Students that majored in subjects that were majority female make similar amount of money with the remaining students

# %% [markdown]
# ## Histograms

# %% [markdown]
# __1)__ Sample Size

# %%
recent_grads['Sample_size'].hist(bins = 50, range = (0,5000))

# %% [markdown]
# The distribution of sample sizes is highly right-skewed.

# %% [markdown]
# __2)__ Median

# %%
recent_grads['Median'].hist(bins = 50)

# %% [markdown]
# The median salary distribution is near normal and common salary amount is around 35k.

# %% [markdown]
# __3)__ Employed

# %%
recent_grads['Full_time'].hist(bins = 50)

# %% [markdown]
# Number of employed is less than 5000 most of the time.

# %% [markdown]
# __4)__ Full Time

# %%
recent_grads['Full_time'].hist(bins = 50)

# %% [markdown]
# Number of Full Time is less than 5000 most of the time.

# %% [markdown]
# __5)__ Sharewomen

# %%
recent_grads['ShareWomen'].hist(bins = 20)

# %% [markdown]
# The distribution of women's share is some left skewed and mos common share is around 70%. The extreme values (very high share and very low share) are mostly not common.

# %% [markdown]
# __6)__ Unemployment Rate

# %%
recent_grads['Unemployment_rate'].hist(bins = 25)

# %% [markdown]
# Unemployment rates are distributed nearly normal with mean = 0.06

# %% [markdown]
# __7)__ Men

# %%
recent_grads['Men'].hist(bins = 100)

# %% [markdown]
# Very few majors have more than 20,000 males. Mostly the men number is less than 1000

# %% [markdown]
# __8)__ Women

# %%
recent_grads['Women'].hist(bins = 50)

# %% [markdown]
# Very few majors have more than 50,000 females. Mostly the women number is less than 7000

# %% [markdown]
# ## Scatter Matrices

# %%
from pandas.plotting import scatter_matrix

# %% [markdown]
# ### 1) Sample Size vs Median

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']])
plt.show()

# %% [markdown]
# We can see that popular majors make moderate amount of money and the highest salaries belong to unpopular majors.

# %% [markdown]
# ### 2) Sample Size, Median, Unemployment Rate

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (10,10))
plt.show()

# %% [markdown]
# Here, we can see that Unemployment rate distribution is a bit right skewed and high-salary-majors have smaller unemployment rate.

# %% [markdown]
# ## Bar Plots

# %% [markdown]
# ### 1) Women Share of Majors:  Minimum 10

# %%
recent_grads.sort_values('ShareWomen')[:10].plot.bar(x = 'Major', y= 'ShareWomen', legend = False)
plt.show()

# %% [markdown]
# ### 2) Women Share of Majors:  Max 10

# %%
recent_grads.sort_values('ShareWomen')[-10:].plot.bar(x = 'Major', y= 'ShareWomen', legend = False)
plt.show()

# %% [markdown]
# ### 3) Unemployment rate of Majors: Minimum 10

# %%
recent_grads.sort_values('Unemployment_rate')[:10].plot.bar(x = 'Major', y ='Unemployment_rate', legend = False)
plt.show()

# %%
recent_grads.sort_values('Unemployment_rate')[-10:].plot.bar(x = 'Major', y ='Unemployment_rate', legend = False)
plt.show()

# %% [markdown]
# ## Grouped Bar Plots

# %% [markdown]
# ### 1) Men vs Women Number: Men's Top 10 Majors

# %%
recent_grads.sort_values('Men', ascending = False)[['Men', 'Women', 'Major']][:10].plot.bar(x = 'Major')
plt.show()

# %% [markdown]
# ### 2) Men vs Women Number: Men's Minimum 10 Majors

# %%
recent_grads.sort_values('Men')[['Men', 'Women', 'Major']][:10].plot.bar(x = 'Major')
plt.show()

# %% [markdown]
# ## Stacked Bar Plots

# %% [markdown]
# ### Men and Women distribution of the Majors with Top Median Salary:

# %%
recent_grads.sort_values('Median', ascending = False)[['Men','Women','Major']][:10].plot.bar(x = 'Major', stacked = True)
plt.show()

# %% [markdown]
# Chemical and Computer enginnering are the majors with large population and significant women number.
